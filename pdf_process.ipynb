# %% [markdown]
# ## Imports and notes

# %%
''' In order for this to work, you must have a zip file of the legal textbook be downloaded to 
your system's Downloads folder '''

# %%
# !pip install pdfplumber

# %%
# !pip install langchain langchain-huggingface langchain-community pypdf langchain_chroma
# Out:
# Collecting langchain
#   Downloading langchain-0.3.21-py3-none-any.whl (1.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 9.9 MB/s eta 0:00:00a 0:00:01
# Collecting langchain-huggingface
#   Downloading langchain_huggingface-0.1.2-py3-none-any.whl (21 kB)
# Collecting langchain-community
#   Downloading langchain_community-0.3.20-py3-none-any.whl (2.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 12.9 MB/s eta 0:00:0000:0100:01
# Collecting pypdf
#   Downloading pypdf-5.4.0-py3-none-any.whl (302 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.3/302.3 kB 13.3 MB/s eta 0:00:00
# Collecting langchain_chroma
#   Downloading langchain_chroma-0.2.2-py3-none-any.whl (11 kB)
# Collecting async-timeout<5.0.0,>=4.0.0
#   Using cached async_timeout-4.0.3-py3-none-any.whl (5.7 kB)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /Users/riyaparikh_computeracct/opt/anaconda3/lib/python3.9/site-packages (from langchain) (1.4.39)
# Requirement already satisfied: requests<3,>=2 in /Users/riyaparikh_computeracct/opt/anaconda3/lib/python3.9/site-packages (from langchain) (2.31.0)
# Collecting langchain-text-splitters<1.0.0,>=0.3.7
#   Downloading langchain_text_splitters-0.3.7-py3-none-any.whl (32 kB)
# Requirement already satisfied: PyYAML>=5.3 in /Users/riyaparikh_computeracct/opt/anaconda3/lib/python3.9/site-packages (from langchain) (6.0)
# Collecting langsmith<0.4,>=0.1.17
#   Downloading langsmith-0.3.18-py3-none-any.whl (351 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 351.9/351.9 kB 13.1 MB/s eta 0:00:00
# Collecting langchain-core<1.0.0,>=0.3.45
#   Downloading langchain_core-0.3.46-py3-none-any.whl (417 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 417.1/417.1 kB 13.1 MB/s eta 0:00:00
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /Users/riyaparikh_computeracct/opt/anaconda3/lib/python3.9/site-packages (from langchain) (2.9.2)
# Collecting huggingface-hub>=0.23.0
#   Downloading huggingface_hub-0.29.3-py3-none-any.whl (468 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 469.0/469.0 kB 12.7 MB/s eta 0:00:00
# Collecting sentence-transformers>=2.6.0
#   Downloading sentence_transformers-3.4.1-py3-none-any.whl (275 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 275.9/275.9 kB 13.1 MB/s eta 0:00:00
# Collecting transformers>=4.39.0
#   Downloading transformers-4.49.0-py3-none-any.whl (10.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.0/10.0 MB 12.3 MB/s eta 0:00:0000:010:01
# Collecting tokenizers>=0.19.1
#   Downloading tokenizers-0.21.1-cp39-abi3-macosx_10_12_x86_64.whl (2.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 8.8 MB/s eta 0:00:00a 0:00:01m
# Collecting tenacity!=8.4.0,<10,>=8.1.0
#   Downloading tenacity-9.0.0-py3-none-any.whl (28 kB)
# Collecting aiohttp<4.0.0,>=3.8.3
#   Downloading aiohttp-3.11.14-cp39-cp39-macosx_10_9_x86_64.whl (469 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 469.8/469.8 kB 11.4 MB/s eta 0:00:00a 0:00:01
# Collecting httpx-sse<1.0.0,>=0.4.0
#   Downloading httpx_sse-0.4.0-py3-none-any.whl (7.8 kB)
# Collecting numpy<3,>=1.26.2
#   Using cached numpy-2.0.2-cp39-cp39-macosx_10_9_x86_64.whl (21.2 MB)
# Collecting pydantic-settings<3.0.0,>=2.4.0
#   Downloading pydantic_settings-2.8.1-py3-none-any.whl (30 kB)
# Collecting dataclasses-json<0.7,>=0.5.7
#   Downloading dataclasses_json-0.6.7-py3-none-any.whl (28 kB)
# Requirement already satisfied: typing_extensions>=4.0 in /Users/riyaparikh_computeracct/opt/anaconda3/lib/python3.9/site-packages (from pypdf) (4.12.2)
# Collecting numpy<3,>=1.26.2
#   Using cached numpy-1.26.4-cp39-cp39-macosx_10_9_x86_64.whl (20.6 MB)
# Collecting chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0
#   Downloading chromadb-0.6.3-py3-none-any.whl (611 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 611.1/611.1 kB 11.3 MB/s eta 0:00:00a 0:00:01
# Collecting multidict<7.0,>=4.5
#   Downloading multidict-6.2.0-cp39-cp39-macosx_10_9_x86_64.whl (29 kB)
# Collecting yarl<2.0,>=1.17.0
#   Downloading yarl-1.18.3-cp39-cp39-macosx_10_9_x86_64.whl (94 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 95.0/95.0 kB 5.6 MB/s eta 0:00:00
# Collecting aiohappyeyeballs>=2.3.0
#   Downloading aiohappyeyeballs-2.6.1-py3-none-any.whl (15 kB)
# Collecting propcache>=0.2.0
#   Downloading propcache-0.3.0-cp39-cp39-macosx_10_9_x86_64.whl (46 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.4/46.4 kB 5.3 MB/s eta 0:00:00
# Collecting aiosignal>=1.1.2
#   Downloading aiosignal-1.3.2-py2.py3-none-any.whl (7.6 kB)
# Requirement already satisfied: attrs>=17.3.0 in /Users/riyaparikh_computeracct/opt/anaconda3/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (21.4.0)
# Collecting frozenlist>=1.1.1
#   Using cached frozenlist-1.5.0-cp39-cp39-macosx_10_9_x86_64.whl (54 kB)
# Requirement already satisfied: httpx>=0.27.0 in /Users/riyaparikh_computeracct/opt/anaconda3/lib/python3.9/site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain_chroma) (0.27.2)
# Collecting opentelemetry-instrumentation-fastapi>=0.41b0
#   Downloading opentelemetry_instrumentation_fastapi-0.52b0-py3-none-any.whl (12 kB)
# Collecting pypika>=0.48.9
#   Downloading PyPika-0.48.9.tar.gz (67 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.3/67.3 kB 8.9 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting bcrypt>=4.0.1
#   Downloading bcrypt-4.3.0-cp39-abi3-macosx_10_12_universal2.whl (498 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 499.0/499.0 kB 12.9 MB/s eta 0:00:00
# Collecting kubernetes>=28.1.0
#   Downloading kubernetes-32.0.1-py2.py3-none-any.whl (2.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 8.6 MB/s eta 0:00:0000:0100:01m
# Collecting posthog>=2.4.0
#   Downloading posthog-3.21.0-py2.py3-none-any.whl (79 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.6/79.6 kB 5.9 MB/s eta 0:00:00
# Collecting mmh3>=4.0.1
#   Downloading mmh3-5.1.0-cp39-cp39-macosx_10_9_x86_64.whl (40 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.5/40.5 kB 4.7 MB/s eta 0:00:00
# Collecting orjson>=3.9.12
#   Downloading orjson-3.10.15-cp39-cp39-macosx_10_15_x86_64.macosx_11_0_arm64.macosx_10_15_universal2.whl (250 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 250.0/250.0 kB 4.6 MB/s eta 0:00:0000:01
# Collecting opentelemetry-sdk>=1.2.0
#   Downloading opentelemetry_sdk-1.31.0-py3-none-any.whl (118 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 118.9/118.9 kB 1.5 MB/s eta 0:00:00a 0:00:01
# Collecting typer>=0.9.0
#   Downloading typer-0.15.2-py3-none-any.whl (45 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.1/45.1 kB 5.0 MB/s eta 0:00:00
# Collecting tqdm>=4.65.0
#   Downloading tqdm-4.67.1-py3-none-any.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.5/78.5 kB 5.6 MB/s eta 0:00:00
# Collecting opentelemetry-api>=1.2.0
#   Downloading opentelemetry_api-1.31.0-py3-none-any.whl (65 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.1/65.1 kB 5.3 MB/s eta 0:00:00
# Collecting uvicorn[standard]>=0.18.3
#   Downloading uvicorn-0.34.0-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.3/62.3 kB 6.5 MB/s eta 0:00:00
# Requirement already satisfied: grpcio>=1.58.0 in /Users/riyaparikh_computeracct/opt/anaconda3/lib/python3.9/site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain_chroma) (1.67.1)
# Collecting build>=1.0.3
#   Downloading build-1.2.2.post1-py3-none-any.whl (22 kB)
# Collecting overrides>=7.3.1
#   Downloading overrides-7.7.0-py3-none-any.whl (17 kB)
# Collecting importlib-resources
#   Downloading importlib_resources-6.5.2-py3-none-any.whl (37 kB)
# Collecting chroma-hnswlib==0.7.6
#   Downloading chroma_hnswlib-0.7.6-cp39-cp39-macosx_10_9_x86_64.whl (195 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 195.9/195.9 kB 7.3 MB/s eta 0:00:00
# Collecting onnxruntime>=1.14.1
#   Downloading onnxruntime-1.16.3-cp39-cp39-macosx_10_15_x86_64.whl (7.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.1/7.1 MB 9.6 MB/s eta 0:00:00:00:0100:01
# Collecting opentelemetry-exporter-otlp-proto-grpc>=1.2.0
#   Downloading opentelemetry_exporter_otlp_proto_grpc-1.31.0-py3-none-any.whl (18 kB)
# Collecting fastapi>=0.95.2
#   Downloading fastapi-0.115.11-py3-none-any.whl (94 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.9/94.9 kB 6.6 MB/s eta 0:00:00
# Requirement already satisfied: rich>=10.11.0 in /Users/riyaparikh_computeracct/opt/anaconda3/lib/python3.9/site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain_chroma) (13.9.4)
# Collecting marshmallow<4.0.0,>=3.18.0
#   Downloading marshmallow-3.26.1-py3-none-any.whl (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.9/50.9 kB 5.4 MB/s eta 0:00:00
# Collecting typing-inspect<1,>=0.4.0
#   Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Requirement already satisfied: packaging>=20.9 in /Users/riyaparikh_computeracct/opt/anaconda3/lib/python3.9/site-packages (from huggingface-hub>=0.23.0->langchain-huggingface) (21.3)
# Collecting fsspec>=2023.5.0
#   Downloading fsspec-2025.3.0-py3-none-any.whl (193 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 193.6/193.6 kB 10.7 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /Users/riyaparikh_computeracct/opt/anaconda3/lib/python3.9/site-packages (from huggingface-hub>=0.23.0->langchain-huggingface) (3.6.0)
# Collecting packaging>=20.9
#   Downloading packaging-24.2-py3-none-any.whl (65 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.5/65.5 kB 5.5 MB/s eta 0:00:00
# Collecting jsonpatch<2.0,>=1.33
#   Downloading jsonpatch-1.33-py2.py3-none-any.whl (12 kB)
# Collecting zstandard<0.24.0,>=0.23.0
#   Downloading zstandard-0.23.0-cp39-cp39-macosx_10_9_x86_64.whl (788 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 788.7/788.7 kB 13.1 MB/s eta 0:00:00a 0:00:01
# Collecting requests-toolbelt<2.0.0,>=1.0.0
#   Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 7.4 MB/s eta 0:00:00
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/riyaparikh_computeracct/opt/anaconda3/lib/python3.9/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /Users/riyaparikh_computeracct/opt/anaconda3/lib/python3.9/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.23.4)
# Collecting python-dotenv>=0.21.0
#   Downloading python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/riyaparikh_computeracct/opt/anaconda3/lib/python3.9/site-packages (from requests<3,>=2->langchain) (2022.9.24)
# Requirement already satisfied: idna<4,>=2.5 in /Users/riyaparikh_computeracct/opt/anaconda3/lib/python3.9/site-packages (from requests<3,>=2->langchain) (3.3)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/riyaparikh_computeracct/opt/anaconda3/lib/python3.9/site-packages (from requests<3,>=2->langchain) (1.26.11)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/riyaparikh_computeracct/opt/anaconda3/lib/python3.9/site-packages (from requests<3,>=2->langchain) (2.0.4)
# Requirement already satisfied: scikit-learn in /Users/riyaparikh_computeracct/opt/anaconda3/lib/python3.9/site-packages (from sentence-transformers>=2.6.0->langchain-huggingface) (1.0.2)
# Collecting torch>=1.11.0
#   Downloading torch-2.2.2-cp39-none-macosx_10_9_x86_64.whl (150.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 150.8/150.8 MB 5.1 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: scipy in /Users/riyaparikh_computeracct/opt/anaconda3/lib/python3.9/site-packages (from sentence-transformers>=2.6.0->langchain-huggingface) (1.9.1)
# Requirement already satisfied: Pillow in /Users/riyaparikh_computeracct/opt/anaconda3/lib/python3.9/site-packages (from sentence-transformers>=2.6.0->langchain-huggingface) (9.2.0)
# Requirement already satisfied: greenlet!=0.4.17 in /Users/riyaparikh_computeracct/opt/anaconda3/lib/python3.9/site-packages (from SQLAlchemy<3,>=1.4->langchain) (1.1.1)
# Requirement already satisfied: regex!=2019.12.17 in /Users/riyaparikh_computeracct/opt/anaconda3/lib/python3.9/site-packages (from transformers>=4.39.0->langchain-huggingface) (2022.7.9)
# Collecting safetensors>=0.4.1
#   Downloading safetensors-0.5.3-cp38-abi3-macosx_10_12_x86_64.whl (436 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 436.9/436.9 kB 6.8 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: tomli>=1.1.0 in /Users/riyaparikh_computeracct/opt/anaconda3/lib/python3.9/site-packages (from build>=1.0.3->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain_chroma) (2.0.1)
# Collecting pyproject_hooks
#   Downloading pyproject_hooks-1.2.0-py3-none-any.whl (10 kB)
# Requirement already satisfied: importlib-metadata>=4.6 in /Users/riyaparikh_computeracct/opt/anaconda3/lib/python3.9/site-packages (from build>=1.0.3->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain_chroma) (4.11.3)
# Collecting starlette<0.47.0,>=0.40.0
#   Downloading starlette-0.46.1-py3-none-any.whl (71 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.0/72.0 kB 8.5 MB/s eta 0:00:00
# Requirement already satisfied: sniffio in /Users/riyaparikh_computeracct/opt/anaconda3/lib/python3.9/site-packages (from httpx>=0.27.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain_chroma) (1.2.0)
# Requirement already satisfied: anyio in /Users/riyaparikh_computeracct/opt/anaconda3/lib/python3.9/site-packages (from httpx>=0.27.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain_chroma) (3.5.0)
# Requirement already satisfied: httpcore==1.* in /Users/riyaparikh_computeracct/opt/anaconda3/lib/python3.9/site-packages (from httpx>=0.27.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain_chroma) (1.0.5)
# Requirement already satisfied: h11<0.15,>=0.13 in /Users/riyaparikh_computeracct/opt/anaconda3/lib/python3.9/site-packages (from httpcore==1.*->httpx>=0.27.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain_chroma) (0.14.0)
# Collecting jsonpointer>=1.9
#   Downloading jsonpointer-3.0.0-py2.py3-none-any.whl (7.6 kB)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in /Users/riyaparikh_computeracct/opt/anaconda3/lib/python3.9/site-packages (from kubernetes>=28.1.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain_chroma) (0.58.0)
# Collecting requests-oauthlib
#   Downloading requests_oauthlib-2.0.0-py2.py3-none-any.whl (24 kB)
# Collecting google-auth>=1.0.1
#   Downloading google_auth-2.38.0-py2.py3-none-any.whl (210 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 210.8/210.8 kB 9.3 MB/s eta 0:00:00
# Collecting durationpy>=0.7
#   Downloading durationpy-0.9-py3-none-any.whl (3.5 kB)
# Collecting oauthlib>=3.2.2
#   Downloading oauthlib-3.2.2-py3-none-any.whl (151 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 151.7/151.7 kB 9.9 MB/s eta 0:00:00
# Requirement already satisfied: six>=1.9.0 in /Users/riyaparikh_computeracct/opt/anaconda3/lib/python3.9/site-packages (from kubernetes>=28.1.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain_chroma) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in /Users/riyaparikh_computeracct/opt/anaconda3/lib/python3.9/site-packages (from kubernetes>=28.1.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain_chroma) (2.8.2)
# Collecting coloredlogs
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 5.4 MB/s eta 0:00:00
# Requirement already satisfied: protobuf in /Users/riyaparikh_computeracct/opt/anaconda3/lib/python3.9/site-packages (from onnxruntime>=1.14.1->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain_chroma) (4.25.5)
# Requirement already satisfied: flatbuffers in /Users/riyaparikh_computeracct/opt/anaconda3/lib/python3.9/site-packages (from onnxruntime>=1.14.1->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain_chroma) (24.3.25)
# Requirement already satisfied: sympy in /Users/riyaparikh_computeracct/opt/anaconda3/lib/python3.9/site-packages (from onnxruntime>=1.14.1->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain_chroma) (1.10.1)
# Collecting deprecated>=1.2.6
#   Downloading Deprecated-1.2.18-py2.py3-none-any.whl (10.0 kB)
# Collecting importlib-metadata>=4.6
#   Downloading importlib_metadata-8.6.1-py3-none-any.whl (26 kB)
# Collecting googleapis-common-protos~=1.52
#   Downloading googleapis_common_protos-1.69.2-py3-none-any.whl (293 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 293.2/293.2 kB 13.7 MB/s eta 0:00:00
# Collecting opentelemetry-exporter-otlp-proto-common==1.31.0
#   Downloading opentelemetry_exporter_otlp_proto_common-1.31.0-py3-none-any.whl (18 kB)
# Collecting opentelemetry-proto==1.31.0
#   Downloading opentelemetry_proto-1.31.0-py3-none-any.whl (55 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.9/55.9 kB 6.6 MB/s eta 0:00:00
# Collecting protobuf
#   Downloading protobuf-5.29.4-cp38-abi3-macosx_10_9_universal2.whl (417 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 417.8/417.8 kB 11.4 MB/s eta 0:00:00
# Collecting opentelemetry-instrumentation-asgi==0.52b0
#   Downloading opentelemetry_instrumentation_asgi-0.52b0-py3-none-any.whl (16 kB)
# Collecting opentelemetry-semantic-conventions==0.52b0
#   Downloading opentelemetry_semantic_conventions-0.52b0-py3-none-any.whl (183 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 183.4/183.4 kB 9.1 MB/s eta 0:00:00
# Collecting opentelemetry-util-http==0.52b0
#   Downloading opentelemetry_util_http-0.52b0-py3-none-any.whl (7.3 kB)
# Collecting opentelemetry-instrumentation==0.52b0
#   Downloading opentelemetry_instrumentation-0.52b0-py3-none-any.whl (31 kB)
# Requirement already satisfied: wrapt<2.0.0,>=1.0.0 in /Users/riyaparikh_computeracct/opt/anaconda3/lib/python3.9/site-packages (from opentelemetry-instrumentation==0.52b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain_chroma) (1.14.1)
# Collecting asgiref~=3.0
#   Downloading asgiref-3.8.1-py3-none-any.whl (23 kB)
# Collecting monotonic>=1.5
#   Downloading monotonic-1.6-py2.py3-none-any.whl (8.2 kB)
# Collecting backoff>=1.10.0
#   Downloading backoff-2.2.1-py3-none-any.whl (15 kB)
# Requirement already satisfied: distro>=1.5.0 in /Users/riyaparikh_computeracct/opt/anaconda3/lib/python3.9/site-packages (from posthog>=2.4.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain_chroma) (1.9.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/riyaparikh_computeracct/opt/anaconda3/lib/python3.9/site-packages (from rich>=10.11.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain_chroma) (2.18.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/riyaparikh_computeracct/opt/anaconda3/lib/python3.9/site-packages (from rich>=10.11.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain_chroma) (3.0.0)
# Requirement already satisfied: jinja2 in /Users/riyaparikh_computeracct/opt/anaconda3/lib/python3.9/site-packages (from torch>=1.11.0->sentence-transformers>=2.6.0->langchain-huggingface) (2.11.3)
# Requirement already satisfied: networkx in /Users/riyaparikh_computeracct/opt/anaconda3/lib/python3.9/site-packages (from torch>=1.11.0->sentence-transformers>=2.6.0->langchain-huggingface) (2.8.4)
# Requirement already satisfied: click>=8.0.0 in /Users/riyaparikh_computeracct/opt/anaconda3/lib/python3.9/site-packages (from typer>=0.9.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain_chroma) (8.0.4)
# Collecting shellingham>=1.3.0
#   Downloading shellingham-1.5.4-py2.py3-none-any.whl (9.8 kB)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /Users/riyaparikh_computeracct/opt/anaconda3/lib/python3.9/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community) (0.4.3)
# Collecting httptools>=0.6.3
#   Downloading httptools-0.6.4-cp39-cp39-macosx_10_9_universal2.whl (201 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 201.1/201.1 kB 691.4 kB/s eta 0:00:00a 0:00:01
# Collecting websockets>=10.4
#   Downloading websockets-15.0.1-cp39-cp39-macosx_10_9_x86_64.whl (173 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 173.1/173.1 kB 6.7 MB/s eta 0:00:00
# Collecting uvloop!=0.15.0,!=0.15.1,>=0.14.0
#   Downloading uvloop-0.21.0-cp39-cp39-macosx_10_9_x86_64.whl (800 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 800.9/800.9 kB 9.1 MB/s eta 0:00:00a 0:00:01
# Collecting watchfiles>=0.13
#   Downloading watchfiles-1.0.4-cp39-cp39-macosx_10_12_x86_64.whl (394 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 395.0/395.0 kB 9.4 MB/s eta 0:00:0000:01
# Requirement already satisfied: zipp>=3.1.0 in /Users/riyaparikh_computeracct/opt/anaconda3/lib/python3.9/site-packages (from importlib-resources->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain_chroma) (3.8.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/riyaparikh_computeracct/opt/anaconda3/lib/python3.9/site-packages (from scikit-learn->sentence-transformers>=2.6.0->langchain-huggingface) (2.2.0)
# Requirement already satisfied: joblib>=0.11 in /Users/riyaparikh_computeracct/opt/anaconda3/lib/python3.9/site-packages (from scikit-learn->sentence-transformers>=2.6.0->langchain-huggingface) (1.4.2)
# Collecting scipy
#   Downloading scipy-1.13.1-cp39-cp39-macosx_10_9_x86_64.whl (39.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 39.4/39.4 MB 9.0 MB/s eta 0:00:00:00:0100:01
# Collecting rsa<5,>=3.1.4
#   Downloading rsa-4.9-py3-none-any.whl (34 kB)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/riyaparikh_computeracct/opt/anaconda3/lib/python3.9/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain_chroma) (0.2.8)
# Collecting cachetools<6.0,>=2.0.0
#   Downloading cachetools-5.5.2-py3-none-any.whl (10 kB)
# Collecting zipp>=3.1.0
#   Downloading zipp-3.21.0-py3-none-any.whl (9.6 kB)
# Requirement already satisfied: mdurl~=0.1 in /Users/riyaparikh_computeracct/opt/anaconda3/lib/python3.9/site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain_chroma) (0.1.2)
# Collecting anyio
#   Downloading anyio-4.9.0-py3-none-any.whl (100 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100.9/100.9 kB 8.2 MB/s eta 0:00:00
# Collecting exceptiongroup>=1.0.2
#   Using cached exceptiongroup-1.2.2-py3-none-any.whl (16 kB)
# Collecting humanfriendly>=9.1
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 8.7 MB/s eta 0:00:00
# Requirement already satisfied: MarkupSafe>=0.23 in /Users/riyaparikh_computeracct/opt/anaconda3/lib/python3.9/site-packages (from jinja2->torch>=1.11.0->sentence-transformers>=2.6.0->langchain-huggingface) (2.0.1)
# Requirement already satisfied: mpmath>=0.19 in /Users/riyaparikh_computeracct/opt/anaconda3/lib/python3.9/site-packages (from sympy->onnxruntime>=1.14.1->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain_chroma) (1.2.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /Users/riyaparikh_computeracct/opt/anaconda3/lib/python3.9/site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain_chroma) (0.4.8)
# Building wheels for collected packages: pypika
#   Building wheel for pypika (pyproject.toml) ... done
#   Created wheel for pypika: filename=pypika-0.48.9-py2.py3-none-any.whl size=53800 sha256=13584cc2afda580f00cd6f8560d008c113a1078995b75152e27205944fc1d962
#   Stored in directory: /Users/riyaparikh_computeracct/Library/Caches/pip/wheels/f7/02/64/d541eac67ec459309d1fb19e727f58ecf7ffb4a8bf42d4cfe5
# Successfully built pypika
# Installing collected packages: pypika, monotonic, durationpy, zstandard, zipp, websockets, uvloop, uvicorn, typing-inspect, tqdm, tenacity, shellingham, safetensors, rsa, python-dotenv, pyproject_hooks, pypdf, protobuf, propcache, packaging, overrides, orjson, opentelemetry-util-http, oauthlib, numpy, multidict, mmh3, jsonpointer, humanfriendly, httpx-sse, httptools, fsspec, frozenlist, exceptiongroup, deprecated, cachetools, bcrypt, backoff, async-timeout, asgiref, aiohappyeyeballs, yarl, torch, scipy, requests-toolbelt, requests-oauthlib, posthog, opentelemetry-proto, marshmallow, jsonpatch, importlib-resources, importlib-metadata, huggingface-hub, googleapis-common-protos, google-auth, coloredlogs, chroma-hnswlib, anyio, aiosignal, watchfiles, typer, tokenizers, starlette, pydantic-settings, opentelemetry-exporter-otlp-proto-common, opentelemetry-api, onnxruntime, kubernetes, dataclasses-json, build, aiohttp, transformers, opentelemetry-semantic-conventions, langsmith, fastapi, sentence-transformers, opentelemetry-sdk, opentelemetry-instrumentation, langchain-core, opentelemetry-instrumentation-asgi, opentelemetry-exporter-otlp-proto-grpc, langchain-text-splitters, langchain-huggingface, opentelemetry-instrumentation-fastapi, langchain, langchain-community, chromadb, langchain_chroma
#   Attempting uninstall: zipp
#     Found existing installation: zipp 3.8.0
#     Uninstalling zipp-3.8.0:
#       Successfully uninstalled zipp-3.8.0
#   Attempting uninstall: tqdm
#     Found existing installation: tqdm 4.64.1
#     Uninstalling tqdm-4.64.1:
#       Successfully uninstalled tqdm-4.64.1
#   Attempting uninstall: tenacity
#     Found existing installation: tenacity 8.0.1
#     Uninstalling tenacity-8.0.1:
#       Successfully uninstalled tenacity-8.0.1
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 4.25.5
#     Uninstalling protobuf-4.25.5:
#       Successfully uninstalled protobuf-4.25.5
#   Attempting uninstall: packaging
#     Found existing installation: packaging 21.3
#     Uninstalling packaging-21.3:
#       Successfully uninstalled packaging-21.3
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.24.4
#     Uninstalling numpy-1.24.4:
#       Successfully uninstalled numpy-1.24.4
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2022.7.1
#     Uninstalling fsspec-2022.7.1:
#       Successfully uninstalled fsspec-2022.7.1
#   Attempting uninstall: bcrypt
#     Found existing installation: bcrypt 3.2.0
#     Uninstalling bcrypt-3.2.0:
#       Successfully uninstalled bcrypt-3.2.0
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.9.1
#     Uninstalling scipy-1.9.1:
#       Successfully uninstalled scipy-1.9.1
#   Attempting uninstall: importlib-metadata
#     Found existing installation: importlib-metadata 4.11.3
#     Uninstalling importlib-metadata-4.11.3:
#       Successfully uninstalled importlib-metadata-4.11.3
#   Attempting uninstall: anyio
#     Found existing installation: anyio 3.5.0
#     Uninstalling anyio-3.5.0:
#       Successfully uninstalled anyio-3.5.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# daal4py 2021.6.0 requires daal==2021.4.0, which is not installed.
# tensorflow 2.16.2 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3, but you have protobuf 5.29.4 which is incompatible.
# numba 0.55.1 requires numpy<1.22,>=1.18, but you have numpy 1.26.4 which is incompatible.
# jupyter-server 1.18.1 requires anyio<4,>=3.1.0, but you have anyio 4.9.0 which is incompatible.
# Successfully installed aiohappyeyeballs-2.6.1 aiohttp-3.11.14 aiosignal-1.3.2 anyio-4.9.0 asgiref-3.8.1 async-timeout-4.0.3 backoff-2.2.1 bcrypt-4.3.0 build-1.2.2.post1 cachetools-5.5.2 chroma-hnswlib-0.7.6 chromadb-0.6.3 coloredlogs-15.0.1 dataclasses-json-0.6.7 deprecated-1.2.18 durationpy-0.9 exceptiongroup-1.2.2 fastapi-0.115.11 frozenlist-1.5.0 fsspec-2025.3.0 google-auth-2.38.0 googleapis-common-protos-1.69.2 httptools-0.6.4 httpx-sse-0.4.0 huggingface-hub-0.29.3 humanfriendly-10.0 importlib-metadata-8.6.1 importlib-resources-6.5.2 jsonpatch-1.33 jsonpointer-3.0.0 kubernetes-32.0.1 langchain-0.3.21 langchain-community-0.3.20 langchain-core-0.3.46 langchain-huggingface-0.1.2 langchain-text-splitters-0.3.7 langchain_chroma-0.2.2 langsmith-0.3.18 marshmallow-3.26.1 mmh3-5.1.0 monotonic-1.6 multidict-6.2.0 numpy-1.26.4 oauthlib-3.2.2 onnxruntime-1.16.3 opentelemetry-api-1.31.0 opentelemetry-exporter-otlp-proto-common-1.31.0 opentelemetry-exporter-otlp-proto-grpc-1.31.0 opentelemetry-instrumentation-0.52b0 opentelemetry-instrumentation-asgi-0.52b0 opentelemetry-instrumentation-fastapi-0.52b0 opentelemetry-proto-1.31.0 opentelemetry-sdk-1.31.0 opentelemetry-semantic-conventions-0.52b0 opentelemetry-util-http-0.52b0 orjson-3.10.15 overrides-7.7.0 packaging-24.2 posthog-3.21.0 propcache-0.3.0 protobuf-5.29.4 pydantic-settings-2.8.1 pypdf-5.4.0 pypika-0.48.9 pyproject_hooks-1.2.0 python-dotenv-1.0.1 requests-oauthlib-2.0.0 requests-toolbelt-1.0.0 rsa-4.9 safetensors-0.5.3 scipy-1.13.1 sentence-transformers-3.4.1 shellingham-1.5.4 starlette-0.46.1 tenacity-9.0.0 tokenizers-0.21.1 torch-2.2.2 tqdm-4.67.1 transformers-4.49.0 typer-0.15.2 typing-inspect-0.9.0 uvicorn-0.34.0 uvloop-0.21.0 watchfiles-1.0.4 websockets-15.0.1 yarl-1.18.3 zipp-3.21.0 zstandard-0.23.0

# %%
# !pip install chromadb smolagents python-dotenv gradio sentence-transformers
# Out:
# Requirement already satisfied: chromadb in /Users/riyaparikh_computeracct/opt/anaconda3/lib/python3.9/site-packages (0.6.3)
# ERROR: Ignored the following versions that require a different python version: 0.1.0 Requires-Python >=3.10; 0.1.2 Requires-Python >=3.10; 0.1.3 Requires-Python >=3.10; 1.0.0 Requires-Python >=3.10; 1.1.0 Requires-Python >=3.10; 1.10.0 Requires-Python >=3.10; 1.11.0 Requires-Python >=3.10; 1.2.0 Requires-Python >=3.10; 1.2.1 Requires-Python >=3.10; 1.2.2 Requires-Python >=3.10; 1.3.0 Requires-Python >=3.10; 1.4.0 Requires-Python >=3.10; 1.4.1 Requires-Python >=3.10; 1.5.0 Requires-Python >=3.10; 1.5.1 Requires-Python >=3.10; 1.6.0 Requires-Python >=3.10; 1.7.0 Requires-Python >=3.10; 1.8.0 Requires-Python >=3.10; 1.8.1 Requires-Python >=3.10; 1.9.0 Requires-Python >=3.10; 1.9.1 Requires-Python >=3.10; 1.9.2 Requires-Python >=3.10
# ERROR: Could not find a version that satisfies the requirement smolagents (from versions: none)
# ERROR: No matching distribution found for smolagents

# %%
# !pip install openai langchain
# Out:
# Requirement already satisfied: openai in /Users/riyaparikh_computeracct/opt/anaconda3/lib/python3.9/site-packages (1.50.2)
# Requirement already satisfied: langchain in /Users/riyaparikh_computeracct/opt/anaconda3/lib/python3.9/site-packages (0.3.21)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/riyaparikh_computeracct/opt/anaconda3/lib/python3.9/site-packages (from openai) (1.9.0)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /Users/riyaparikh_computeracct/opt/anaconda3/lib/python3.9/site-packages (from openai) (4.12.2)
# Requirement already satisfied: sniffio in /Users/riyaparikh_computeracct/opt/anaconda3/lib/python3.9/site-packages (from openai) (1.2.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /Users/riyaparikh_computeracct/opt/anaconda3/lib/python3.9/site-packages (from openai) (4.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Users/riyaparikh_computeracct/opt/anaconda3/lib/python3.9/site-packages (from openai) (0.27.2)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /Users/riyaparikh_computeracct/opt/anaconda3/lib/python3.9/site-packages (from openai) (2.9.2)
# Requirement already satisfied: tqdm>4 in /Users/riyaparikh_computeracct/opt/anaconda3/lib/python3.9/site-packages (from openai) (4.67.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in /Users/riyaparikh_computeracct/opt/anaconda3/lib/python3.9/site-packages (from openai) (0.5.0)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.45 in /Users/riyaparikh_computeracct/opt/anaconda3/lib/python3.9/site-packages (from langchain) (0.3.46)
# Requirement already satisfied: PyYAML>=5.3 in /Users/riyaparikh_computeracct/opt/anaconda3/lib/python3.9/site-packages (from langchain) (6.0)
# Requirement already satisfied: langsmith<0.4,>=0.1.17 in /Users/riyaparikh_computeracct/opt/anaconda3/lib/python3.9/site-packages (from langchain) (0.3.18)
# Requirement already satisfied: requests<3,>=2 in /Users/riyaparikh_computeracct/opt/anaconda3/lib/python3.9/site-packages (from langchain) (2.31.0)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in /Users/riyaparikh_computeracct/opt/anaconda3/lib/python3.9/site-packages (from langchain) (4.0.3)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.7 in /Users/riyaparikh_computeracct/opt/anaconda3/lib/python3.9/site-packages (from langchain) (0.3.7)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /Users/riyaparikh_computeracct/opt/anaconda3/lib/python3.9/site-packages (from langchain) (1.4.39)
# Requirement already satisfied: idna>=2.8 in /Users/riyaparikh_computeracct/opt/anaconda3/lib/python3.9/site-packages (from anyio<5,>=3.5.0->openai) (3.3)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /Users/riyaparikh_computeracct/opt/anaconda3/lib/python3.9/site-packages (from anyio<5,>=3.5.0->openai) (1.2.2)
# Requirement already satisfied: httpcore==1.* in /Users/riyaparikh_computeracct/opt/anaconda3/lib/python3.9/site-packages (from httpx<1,>=0.23.0->openai) (1.0.5)
# Requirement already satisfied: certifi in /Users/riyaparikh_computeracct/opt/anaconda3/lib/python3.9/site-packages (from httpx<1,>=0.23.0->openai) (2022.9.24)
# Requirement already satisfied: h11<0.15,>=0.13 in /Users/riyaparikh_computeracct/opt/anaconda3/lib/python3.9/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.14.0)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /Users/riyaparikh_computeracct/opt/anaconda3/lib/python3.9/site-packages (from langchain-core<1.0.0,>=0.3.45->langchain) (1.33)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /Users/riyaparikh_computeracct/opt/anaconda3/lib/python3.9/site-packages (from langchain-core<1.0.0,>=0.3.45->langchain) (9.0.0)
# Requirement already satisfied: packaging<25,>=23.2 in /Users/riyaparikh_computeracct/opt/anaconda3/lib/python3.9/site-packages (from langchain-core<1.0.0,>=0.3.45->langchain) (24.2)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /Users/riyaparikh_computeracct/opt/anaconda3/lib/python3.9/site-packages (from langsmith<0.4,>=0.1.17->langchain) (3.10.15)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in /Users/riyaparikh_computeracct/opt/anaconda3/lib/python3.9/site-packages (from langsmith<0.4,>=0.1.17->langchain) (0.23.0)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /Users/riyaparikh_computeracct/opt/anaconda3/lib/python3.9/site-packages (from langsmith<0.4,>=0.1.17->langchain) (1.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/riyaparikh_computeracct/opt/anaconda3/lib/python3.9/site-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /Users/riyaparikh_computeracct/opt/anaconda3/lib/python3.9/site-packages (from pydantic<3,>=1.9.0->openai) (2.23.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/riyaparikh_computeracct/opt/anaconda3/lib/python3.9/site-packages (from requests<3,>=2->langchain) (1.26.11)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/riyaparikh_computeracct/opt/anaconda3/lib/python3.9/site-packages (from requests<3,>=2->langchain) (2.0.4)
# Requirement already satisfied: greenlet!=0.4.17 in /Users/riyaparikh_computeracct/opt/anaconda3/lib/python3.9/site-packages (from SQLAlchemy<3,>=1.4->langchain) (1.1.1)
# Requirement already satisfied: jsonpointer>=1.9 in /Users/riyaparikh_computeracct/opt/anaconda3/lib/python3.9/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.45->langchain) (3.0.0)

# %%
# !pip install --upgrade langchain langchain-community langchain-huggingface chromadb sentence-transformers
# Out:
# Requirement already satisfied: langchain in /Users/riyaparikh_computeracct/opt/anaconda3/lib/python3.9/site-packages (0.3.21)
# Requirement already satisfied: langchain-community in /Users/riyaparikh_computeracct/opt/anaconda3/lib/python3.9/site-packages (0.3.20)
# Requirement already satisfied: langchain-huggingface in /Users/riyaparikh_computeracct/opt/anaconda3/lib/python3.9/site-packages (0.1.2)
# Requirement already satisfied: chromadb in /Users/riyaparikh_computeracct/opt/anaconda3/lib/python3.9/site-packages (0.6.3)
# Requirement already satisfied: sentence-transformers in /Users/riyaparikh_computeracct/opt/anaconda3/lib/python3.9/site-packages (3.4.1)
# Requirement already satisfied: langsmith<0.4,>=0.1.17 in /Users/riyaparikh_computeracct/opt/anaconda3/lib/python3.9/site-packages (from langchain) (0.3.18)
# Requirement already satisfied: requests<3,>=2 in /Users/riyaparikh_computeracct/opt/anaconda3/lib/python3.9/site-packages (from langchain) (2.31.0)
# Requirement already satisfied: PyYAML>=5.3 in /Users/riyaparikh_computeracct/opt/anaconda3/lib/python3.9/site-packages (from langchain) (6.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /Users/riyaparikh_computeracct/opt/anaconda3/lib/python3.9/site-packages (from langchain) (2.9.2)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.45 in /Users/riyaparikh_computeracct/opt/anaconda3/lib/python3.9/site-packages (from langchain) (0.3.46)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in /Users/riyaparikh_computeracct/opt/anaconda3/lib/python3.9/site-packages (from langchain) (4.0.3)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /Users/riyaparikh_computeracct/opt/anaconda3/lib/python3.9/site-packages (from langchain) (1.4.39)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.7 in /Users/riyaparikh_computeracct/opt/anaconda3/lib/python3.9/site-packages (from langchain) (0.3.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.4.0 in /Users/riyaparikh_computeracct/opt/anaconda3/lib/python3.9/site-packages (from langchain-community) (2.8.1)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /Users/riyaparikh_computeracct/opt/anaconda3/lib/python3.9/site-packages (from langchain-community) (3.11.14)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in /Users/riyaparikh_computeracct/opt/anaconda3/lib/python3.9/site-packages (from langchain-community) (0.4.0)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in /Users/riyaparikh_computeracct/opt/anaconda3/lib/python3.9/site-packages (from langchain-community) (9.0.0)
# Requirement already satisfied: numpy<3,>=1.26.2 in /Users/riyaparikh_computeracct/opt/anaconda3/lib/python3.9/site-packages (from langchain-community) (1.26.4)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in /Users/riyaparikh_computeracct/opt/anaconda3/lib/python3.9/site-packages (from langchain-community) (0.6.7)
# Requirement already satisfied: huggingface-hub>=0.23.0 in /Users/riyaparikh_computeracct/opt/anaconda3/lib/python3.9/site-packages (from langchain-huggingface) (0.29.3)
# Requirement already satisfied: tokenizers>=0.19.1 in /Users/riyaparikh_computeracct/opt/anaconda3/lib/python3.9/site-packages (from langchain-huggingface) (0.21.1)
# Requirement already satisfied: transformers>=4.39.0 in /Users/riyaparikh_computeracct/opt/anaconda3/lib/python3.9/site-packages (from langchain-huggingface) (4.49.0)
# Requirement already satisfied: bcrypt>=4.0.1 in /Users/riyaparikh_computeracct/opt/anaconda3/lib/python3.9/site-packages (from chromadb) (4.3.0)
# Requirement already satisfied: chroma-hnswlib==0.7.6 in /Users/riyaparikh_computeracct/opt/anaconda3/lib/python3.9/site-packages (from chromadb) (0.7.6)
# Requirement already satisfied: typing_extensions>=4.5.0 in /Users/riyaparikh_computeracct/opt/anaconda3/lib/python3.9/site-packages (from chromadb) (4.12.2)
# Requirement already satisfied: fastapi>=0.95.2 in /Users/riyaparikh_computeracct/opt/anaconda3/lib/python3.9/site-packages (from chromadb) (0.115.11)
# Requirement already satisfied: mmh3>=4.0.1 in /Users/riyaparikh_computeracct/opt/anaconda3/lib/python3.9/site-packages (from chromadb) (5.1.0)
# Requirement already satisfied: overrides>=7.3.1 in /Users/riyaparikh_computeracct/opt/anaconda3/lib/python3.9/site-packages (from chromadb) (7.7.0)
# Requirement already satisfied: orjson>=3.9.12 in /Users/riyaparikh_computeracct/opt/anaconda3/lib/python3.9/site-packages (from chromadb) (3.10.15)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in /Users/riyaparikh_computeracct/opt/anaconda3/lib/python3.9/site-packages (from chromadb) (1.31.0)
# Requirement already satisfied: rich>=10.11.0 in /Users/riyaparikh_computeracct/opt/anaconda3/lib/python3.9/site-packages (from chromadb) (13.9.4)
# Requirement already satisfied: kubernetes>=28.1.0 in /Users/riyaparikh_computeracct/opt/anaconda3/lib/python3.9/site-packages (from chromadb) (32.0.1)
# Requirement already satisfied: importlib-resources in /Users/riyaparikh_computeracct/opt/anaconda3/lib/python3.9/site-packages (from chromadb) (6.5.2)
# Requirement already satisfied: posthog>=2.4.0 in /Users/riyaparikh_computeracct/opt/anaconda3/lib/python3.9/site-packages (from chromadb) (3.21.0)
# Requirement already satisfied: grpcio>=1.58.0 in /Users/riyaparikh_computeracct/opt/anaconda3/lib/python3.9/site-packages (from chromadb) (1.67.1)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in /Users/riyaparikh_computeracct/opt/anaconda3/lib/python3.9/site-packages (from chromadb) (1.31.0)
# Requirement already satisfied: tqdm>=4.65.0 in /Users/riyaparikh_computeracct/opt/anaconda3/lib/python3.9/site-packages (from chromadb) (4.67.1)
# Requirement already satisfied: uvicorn[standard]>=0.18.3 in /Users/riyaparikh_computeracct/opt/anaconda3/lib/python3.9/site-packages (from chromadb) (0.34.0)
# Requirement already satisfied: pypika>=0.48.9 in /Users/riyaparikh_computeracct/opt/anaconda3/lib/python3.9/site-packages (from chromadb) (0.48.9)
# Requirement already satisfied: onnxruntime>=1.14.1 in /Users/riyaparikh_computeracct/opt/anaconda3/lib/python3.9/site-packages (from chromadb) (1.16.3)
# Requirement already satisfied: httpx>=0.27.0 in /Users/riyaparikh_computeracct/opt/anaconda3/lib/python3.9/site-packages (from chromadb) (0.27.2)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in /Users/riyaparikh_computeracct/opt/anaconda3/lib/python3.9/site-packages (from chromadb) (1.31.0)
# Requirement already satisfied: build>=1.0.3 in /Users/riyaparikh_computeracct/opt/anaconda3/lib/python3.9/site-packages (from chromadb) (1.2.2.post1)
# Requirement already satisfied: opentelemetry-instrumentation-fastapi>=0.41b0 in /Users/riyaparikh_computeracct/opt/anaconda3/lib/python3.9/site-packages (from chromadb) (0.52b0)
# Requirement already satisfied: typer>=0.9.0 in /Users/riyaparikh_computeracct/opt/anaconda3/lib/python3.9/site-packages (from chromadb) (0.15.2)
# Requirement already satisfied: scipy in /Users/riyaparikh_computeracct/opt/anaconda3/lib/python3.9/site-packages (from sentence-transformers) (1.13.1)
# Requirement already satisfied: Pillow in /Users/riyaparikh_computeracct/opt/anaconda3/lib/python3.9/site-packages (from sentence-transformers) (9.2.0)
# Requirement already satisfied: torch>=1.11.0 in /Users/riyaparikh_computeracct/opt/anaconda3/lib/python3.9/site-packages (from sentence-transformers) (2.2.2)
# Requirement already satisfied: scikit-learn in /Users/riyaparikh_computeracct/opt/anaconda3/lib/python3.9/site-packages (from sentence-transformers) (1.0.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /Users/riyaparikh_computeracct/opt/anaconda3/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/riyaparikh_computeracct/opt/anaconda3/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.3.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/riyaparikh_computeracct/opt/anaconda3/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/riyaparikh_computeracct/opt/anaconda3/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.2.0)
# Requirement already satisfied: propcache>=0.2.0 in /Users/riyaparikh_computeracct/opt/anaconda3/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.3.0)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /Users/riyaparikh_computeracct/opt/anaconda3/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.18.3)
# Requirement already satisfied: attrs>=17.3.0 in /Users/riyaparikh_computeracct/opt/anaconda3/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (21.4.0)
# Requirement already satisfied: pyproject_hooks in /Users/riyaparikh_computeracct/opt/anaconda3/lib/python3.9/site-packages (from build>=1.0.3->chromadb) (1.2.0)
# Requirement already satisfied: tomli>=1.1.0 in /Users/riyaparikh_computeracct/opt/anaconda3/lib/python3.9/site-packages (from build>=1.0.3->chromadb) (2.0.1)
# Requirement already satisfied: packaging>=19.1 in /Users/riyaparikh_computeracct/opt/anaconda3/lib/python3.9/site-packages (from build>=1.0.3->chromadb) (24.2)
# Requirement already satisfied: importlib-metadata>=4.6 in /Users/riyaparikh_computeracct/opt/anaconda3/lib/python3.9/site-packages (from build>=1.0.3->chromadb) (8.6.1)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /Users/riyaparikh_computeracct/opt/anaconda3/lib/python3.9/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /Users/riyaparikh_computeracct/opt/anaconda3/lib/python3.9/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community) (0.9.0)
# Requirement already satisfied: starlette<0.47.0,>=0.40.0 in /Users/riyaparikh_computeracct/opt/anaconda3/lib/python3.9/site-packages (from fastapi>=0.95.2->chromadb) (0.46.1)
# Requirement already satisfied: idna in /Users/riyaparikh_computeracct/opt/anaconda3/lib/python3.9/site-packages (from httpx>=0.27.0->chromadb) (3.3)
# Requirement already satisfied: sniffio in /Users/riyaparikh_computeracct/opt/anaconda3/lib/python3.9/site-packages (from httpx>=0.27.0->chromadb) (1.2.0)
# Requirement already satisfied: httpcore==1.* in /Users/riyaparikh_computeracct/opt/anaconda3/lib/python3.9/site-packages (from httpx>=0.27.0->chromadb) (1.0.5)
# Requirement already satisfied: certifi in /Users/riyaparikh_computeracct/opt/anaconda3/lib/python3.9/site-packages (from httpx>=0.27.0->chromadb) (2022.9.24)
# Requirement already satisfied: anyio in /Users/riyaparikh_computeracct/opt/anaconda3/lib/python3.9/site-packages (from httpx>=0.27.0->chromadb) (4.9.0)
# Requirement already satisfied: h11<0.15,>=0.13 in /Users/riyaparikh_computeracct/opt/anaconda3/lib/python3.9/site-packages (from httpcore==1.*->httpx>=0.27.0->chromadb) (0.14.0)
# Requirement already satisfied: filelock in /Users/riyaparikh_computeracct/opt/anaconda3/lib/python3.9/site-packages (from huggingface-hub>=0.23.0->langchain-huggingface) (3.6.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/riyaparikh_computeracct/opt/anaconda3/lib/python3.9/site-packages (from huggingface-hub>=0.23.0->langchain-huggingface) (2025.3.0)
# Requirement already satisfied: requests-oauthlib in /Users/riyaparikh_computeracct/opt/anaconda3/lib/python3.9/site-packages (from kubernetes>=28.1.0->chromadb) (2.0.0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in /Users/riyaparikh_computeracct/opt/anaconda3/lib/python3.9/site-packages (from kubernetes>=28.1.0->chromadb) (0.58.0)
# Requirement already satisfied: google-auth>=1.0.1 in /Users/riyaparikh_computeracct/opt/anaconda3/lib/python3.9/site-packages (from kubernetes>=28.1.0->chromadb) (2.38.0)
# Requirement already satisfied: durationpy>=0.7 in /Users/riyaparikh_computeracct/opt/anaconda3/lib/python3.9/site-packages (from kubernetes>=28.1.0->chromadb) (0.9)
# Requirement already satisfied: six>=1.9.0 in /Users/riyaparikh_computeracct/opt/anaconda3/lib/python3.9/site-packages (from kubernetes>=28.1.0->chromadb) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in /Users/riyaparikh_computeracct/opt/anaconda3/lib/python3.9/site-packages (from kubernetes>=28.1.0->chromadb) (2.8.2)
# Requirement already satisfied: urllib3>=1.24.2 in /Users/riyaparikh_computeracct/opt/anaconda3/lib/python3.9/site-packages (from kubernetes>=28.1.0->chromadb) (1.26.11)
# Requirement already satisfied: oauthlib>=3.2.2 in /Users/riyaparikh_computeracct/opt/anaconda3/lib/python3.9/site-packages (from kubernetes>=28.1.0->chromadb) (3.2.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /Users/riyaparikh_computeracct/opt/anaconda3/lib/python3.9/site-packages (from langchain-core<1.0.0,>=0.3.45->langchain) (1.33)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /Users/riyaparikh_computeracct/opt/anaconda3/lib/python3.9/site-packages (from langsmith<0.4,>=0.1.17->langchain) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in /Users/riyaparikh_computeracct/opt/anaconda3/lib/python3.9/site-packages (from langsmith<0.4,>=0.1.17->langchain) (0.23.0)
# Requirement already satisfied: sympy in /Users/riyaparikh_computeracct/opt/anaconda3/lib/python3.9/site-packages (from onnxruntime>=1.14.1->chromadb) (1.10.1)
# Requirement already satisfied: coloredlogs in /Users/riyaparikh_computeracct/opt/anaconda3/lib/python3.9/site-packages (from onnxruntime>=1.14.1->chromadb) (15.0.1)
# Requirement already satisfied: protobuf in /Users/riyaparikh_computeracct/opt/anaconda3/lib/python3.9/site-packages (from onnxruntime>=1.14.1->chromadb) (5.29.4)
# Requirement already satisfied: flatbuffers in /Users/riyaparikh_computeracct/opt/anaconda3/lib/python3.9/site-packages (from onnxruntime>=1.14.1->chromadb) (24.3.25)
# Requirement already satisfied: deprecated>=1.2.6 in /Users/riyaparikh_computeracct/opt/anaconda3/lib/python3.9/site-packages (from opentelemetry-api>=1.2.0->chromadb) (1.2.18)
# Requirement already satisfied: opentelemetry-proto==1.31.0 in /Users/riyaparikh_computeracct/opt/anaconda3/lib/python3.9/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.31.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.31.0 in /Users/riyaparikh_computeracct/opt/anaconda3/lib/python3.9/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.31.0)
# Requirement already satisfied: googleapis-common-protos~=1.52 in /Users/riyaparikh_computeracct/opt/anaconda3/lib/python3.9/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.69.2)
# Requirement already satisfied: opentelemetry-util-http==0.52b0 in /Users/riyaparikh_computeracct/opt/anaconda3/lib/python3.9/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.52b0)
# Requirement already satisfied: opentelemetry-instrumentation-asgi==0.52b0 in /Users/riyaparikh_computeracct/opt/anaconda3/lib/python3.9/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.52b0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.52b0 in /Users/riyaparikh_computeracct/opt/anaconda3/lib/python3.9/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.52b0)
# Requirement already satisfied: opentelemetry-instrumentation==0.52b0 in /Users/riyaparikh_computeracct/opt/anaconda3/lib/python3.9/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.52b0)
# Requirement already satisfied: wrapt<2.0.0,>=1.0.0 in /Users/riyaparikh_computeracct/opt/anaconda3/lib/python3.9/site-packages (from opentelemetry-instrumentation==0.52b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (1.14.1)
# Requirement already satisfied: asgiref~=3.0 in /Users/riyaparikh_computeracct/opt/anaconda3/lib/python3.9/site-packages (from opentelemetry-instrumentation-asgi==0.52b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (3.8.1)
# Requirement already satisfied: monotonic>=1.5 in /Users/riyaparikh_computeracct/opt/anaconda3/lib/python3.9/site-packages (from posthog>=2.4.0->chromadb) (1.6)
# Requirement already satisfied: backoff>=1.10.0 in /Users/riyaparikh_computeracct/opt/anaconda3/lib/python3.9/site-packages (from posthog>=2.4.0->chromadb) (2.2.1)
# Requirement already satisfied: distro>=1.5.0 in /Users/riyaparikh_computeracct/opt/anaconda3/lib/python3.9/site-packages (from posthog>=2.4.0->chromadb) (1.9.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/riyaparikh_computeracct/opt/anaconda3/lib/python3.9/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /Users/riyaparikh_computeracct/opt/anaconda3/lib/python3.9/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.23.4)
# Requirement already satisfied: python-dotenv>=0.21.0 in /Users/riyaparikh_computeracct/opt/anaconda3/lib/python3.9/site-packages (from pydantic-settings<3.0.0,>=2.4.0->langchain-community) (1.0.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/riyaparikh_computeracct/opt/anaconda3/lib/python3.9/site-packages (from requests<3,>=2->langchain) (2.0.4)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/riyaparikh_computeracct/opt/anaconda3/lib/python3.9/site-packages (from rich>=10.11.0->chromadb) (2.18.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/riyaparikh_computeracct/opt/anaconda3/lib/python3.9/site-packages (from rich>=10.11.0->chromadb) (3.0.0)
# Requirement already satisfied: greenlet!=0.4.17 in /Users/riyaparikh_computeracct/opt/anaconda3/lib/python3.9/site-packages (from SQLAlchemy<3,>=1.4->langchain) (1.1.1)
# Requirement already satisfied: jinja2 in /Users/riyaparikh_computeracct/opt/anaconda3/lib/python3.9/site-packages (from torch>=1.11.0->sentence-transformers) (2.11.3)
# Requirement already satisfied: networkx in /Users/riyaparikh_computeracct/opt/anaconda3/lib/python3.9/site-packages (from torch>=1.11.0->sentence-transformers) (2.8.4)
# Requirement already satisfied: safetensors>=0.4.1 in /Users/riyaparikh_computeracct/opt/anaconda3/lib/python3.9/site-packages (from transformers>=4.39.0->langchain-huggingface) (0.5.3)
# Requirement already satisfied: regex!=2019.12.17 in /Users/riyaparikh_computeracct/opt/anaconda3/lib/python3.9/site-packages (from transformers>=4.39.0->langchain-huggingface) (2022.7.9)
# Requirement already satisfied: click>=8.0.0 in /Users/riyaparikh_computeracct/opt/anaconda3/lib/python3.9/site-packages (from typer>=0.9.0->chromadb) (8.0.4)
# Requirement already satisfied: shellingham>=1.3.0 in /Users/riyaparikh_computeracct/opt/anaconda3/lib/python3.9/site-packages (from typer>=0.9.0->chromadb) (1.5.4)
# Requirement already satisfied: watchfiles>=0.13 in /Users/riyaparikh_computeracct/opt/anaconda3/lib/python3.9/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.0.4)
# Requirement already satisfied: websockets>=10.4 in /Users/riyaparikh_computeracct/opt/anaconda3/lib/python3.9/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (15.0.1)
# Requirement already satisfied: httptools>=0.6.3 in /Users/riyaparikh_computeracct/opt/anaconda3/lib/python3.9/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.6.4)
# Requirement already satisfied: uvloop!=0.15.0,!=0.15.1,>=0.14.0 in /Users/riyaparikh_computeracct/opt/anaconda3/lib/python3.9/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.21.0)
# Requirement already satisfied: zipp>=3.1.0 in /Users/riyaparikh_computeracct/opt/anaconda3/lib/python3.9/site-packages (from importlib-resources->chromadb) (3.21.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/riyaparikh_computeracct/opt/anaconda3/lib/python3.9/site-packages (from scikit-learn->sentence-transformers) (2.2.0)
# Requirement already satisfied: joblib>=0.11 in /Users/riyaparikh_computeracct/opt/anaconda3/lib/python3.9/site-packages (from scikit-learn->sentence-transformers) (1.4.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/riyaparikh_computeracct/opt/anaconda3/lib/python3.9/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/riyaparikh_computeracct/opt/anaconda3/lib/python3.9/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (4.9)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /Users/riyaparikh_computeracct/opt/anaconda3/lib/python3.9/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (5.5.2)
# Requirement already satisfied: jsonpointer>=1.9 in /Users/riyaparikh_computeracct/opt/anaconda3/lib/python3.9/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.45->langchain) (3.0.0)
# Requirement already satisfied: mdurl~=0.1 in /Users/riyaparikh_computeracct/opt/anaconda3/lib/python3.9/site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb) (0.1.2)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /Users/riyaparikh_computeracct/opt/anaconda3/lib/python3.9/site-packages (from anyio->httpx>=0.27.0->chromadb) (1.2.2)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /Users/riyaparikh_computeracct/opt/anaconda3/lib/python3.9/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community) (0.4.3)
# Requirement already satisfied: humanfriendly>=9.1 in /Users/riyaparikh_computeracct/opt/anaconda3/lib/python3.9/site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb) (10.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /Users/riyaparikh_computeracct/opt/anaconda3/lib/python3.9/site-packages (from jinja2->torch>=1.11.0->sentence-transformers) (2.0.1)
# Requirement already satisfied: mpmath>=0.19 in /Users/riyaparikh_computeracct/opt/anaconda3/lib/python3.9/site-packages (from sympy->onnxruntime>=1.14.1->chromadb) (1.2.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /Users/riyaparikh_computeracct/opt/anaconda3/lib/python3.9/site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.4.8)

# %%
print(os.getcwd())
base_dir = input("Enter the base directory path for the dataset: ")

# Verify the path
print("Base directory set to:", base_dir)
# Out:
# /Users/riyaparikh_computeracct/Downloads
# Enter the base directory path for the dataset: /Users/riyaparikh_computeracct/Downloads
# Base directory set to: /Users/riyaparikh_computeracct/Downloads

# %%
import zipfile
import pdfplumber
import os
import re
import shutil
from io import BytesIO
import pandas as pd
import numpy as np
from langchain_community.document_loaders import DirectoryLoader, PyPDFLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain_huggingface import HuggingFaceEmbeddings
from langchain_community.vectorstores import Chroma
from langchain.docstore.document import Document
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.embeddings import OpenAIEmbeddings
import torch
torch.set_num_threads(1)
os.environ["OPENAI_API_KEY"] = "your-api-key"

def extract_zip(uploaded_zip_path, extract_to="temp_pdfs"):
    """Extracts a zipped folder containing PDFs."""
    os.makedirs(extract_to, exist_ok=True)  # Ensure extraction folder exists

    with zipfile.ZipFile(uploaded_zip_path, 'r') as zip_ref:
        zip_ref.extractall(extract_to)

    pdf_files = []
    for root, _, files in os.walk(extract_to):
        for file in files:
            if file.lower().endswith(".pdf"):
                pdf_files.append(os.path.join(root, file))

    return pdf_files

def pdf_to_markdown_string(pdf_path):
    """Extracts structured content from a PDF and chunks by major sections."""
    with pdfplumber.open(pdf_path) as pdf:
        sections = {}
        current_section = None
        first_page_skipped = False

        for page_num, page in enumerate(pdf.pages):
            if not first_page_skipped:
                first_page_skipped = True
                continue  # Skip the first page (assumed to be TOC)

            text = page.extract_text()
            if not text:
                continue

            lines = text.split("\n")

            for line in lines:
                # Detecting major section headings using regex patterns
                # Detects section headings based on patterns like "Chapter X", bold text, or all-uppercase words
                if re.match(r"^\s*Chapter \d+:?", line) or re.match(r"^[A-Z][A-Z\s]+$", line.strip()):
                    current_section = line.strip()
                    sections[current_section] = sections.get(current_section, "")
                elif current_section:
                    sections[current_section] += line.strip() + "\n"

    # Convert to a list of markdown chunks
    markdown_chunks = []
    for section, content in sections.items():
        markdown_chunks.append(f"## {section}\n\n{content.strip()}\n\n")

    return markdown_chunks

def load_and_process_pdfs(zip_path):
    """Processes a zipped folder of PDFs and splits into smaller chunks for vector storage."""
    pdf_files = extract_zip(zip_path)
    all_chunks = []

    for pdf in pdf_files:
        markdown_sections = pdf_to_markdown_string(pdf)
        
        # Use a text splitter to break sections into smaller chunks
        text_splitter = RecursiveCharacterTextSplitter(
            chunk_size=500,  # Adjust chunk size as needed?? Will need to experiment with this and how it interacts with the prompts we try out too
            chunk_overlap=50 # Made overlapping size smaller 
        )

        for section in markdown_sections:
            chunks = text_splitter.split_text(section)
            for chunk in chunks:
                all_chunks.append(Document(page_content=chunk, metadata={"source": os.path.basename(pdf)}))

    return all_chunks

def create_vector_store(chunks, persist_dir: str):
    """Create and persist a Chroma vector store using OpenAI embeddings."""
    
    if os.path.exists(persist_dir):
        print(f"Removing existing vector store from {persist_dir}")
        shutil.rmtree(persist_dir)  # Try commenting this out if issues persist

    # Debugging info
    print(f"Total chunks received for vector store: {len(chunks)}")
    if chunks:
        print(f"Example chunk: {chunks[0].page_content[:300]}")

    try:
        # Initialize OpenAI Embeddings
        embedding_model = OpenAIEmbeddings()

        print("Building and saving the new vector store with OpenAI embeddings...")
        vector_db = Chroma.from_documents(
            documents=chunks,
            embedding=embedding_model,
            persist_directory=persist_dir
        )
        return vector_db

    except Exception as e:
        print(f"Error creating vector store: {e}")
        return None  # Return None if an error occurs


def query_vector_store(vector_db, query):
    """Finds the most relevant chunks based on the query."""
    results = vector_db.similarity_search(query, k=3)  # Retrieve top 3 most relevant results
    return [doc.page_content for doc in results]

def main():
    zip_file_path = "/Users/riyaparikh_computeracct/Downloads/legaltextbook.zip"
    vector_db_dir = os.path.join(os.getcwd(), "/chroma_db") # Added slash

    print("Processing PDFs into chunks...")
    document_chunks = load_and_process_pdfs(zip_file_path)
    print(f"Generated {len(document_chunks)} document chunks.")

    print("Building the vector store...")
    vector_db = create_vector_store(document_chunks, vector_db_dir)
    print(f"Vector store successfully created at {vector_db_dir}")

    # Example query
    user_query = "What are the legal protections for mobile home tenants in Massachusetts?"
    results = query_vector_store(vector_db, user_query)

    print("\nTop Matching Results:")
    for idx, result in enumerate(results, 1):
        print(f"{idx}. {result[:300]}...")  # Display first 300 chars
        
        
if __name__ == "__main__":
    main()
# Out:
# Processing PDFs into chunks...
# Generated 2934 document chunks.
# Building the vector store...
# Total chunks received for vector store: 2934
# Example chunk: ## Chapter 6: Utilities ▲
